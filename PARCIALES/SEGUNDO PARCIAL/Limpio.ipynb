# %% [markdown]
# # LABORATORIO 6

# %% [markdown]
# Este es un entrenamiento y prueba de aprendizaje por refuerzo del juego de carta Black Jack
# donde elaboramos un modelo que logra jugar el juego de una manera efectiva
#
# Grupo 4
# Integrantes
#
# 1. Aly Delgado Danner Abel
# 2. Lujan Renteria
# 3. Itzel Emily Velasquez Guerra
# 4. Julio Cesar Ortega Albarado
# 5. Rojas Vasquez Sheila

# %% [markdown]
# **Descripción del trabajo**
#
# En este proyecto, desarrollamos un agente de Q-learning para el entorno Blackjack-v1 de Gymnasium. Inicializamos una Q-table con ceros para todas las combinaciones posibles de estados y acciones. Utilizamos una política ε-greedy para equilibrar la exploración y la explotación, permitiendo al agente descubrir nuevas estrategias mientras aprovecha el conocimiento adquirido.
#
# El agente fue entrenado durante 100,000 episodios, actualizando la Q-table en cada paso utilizando la ecuación de Bellman. Registramos las recompensas obtenidas en cada episodio y aplicamos un promedio móvil para suavizar los datos y mejorar la visualización. Finalmente, graficamos las recompensas para visualizar el progreso del aprendizaje del agente y guardamos la Q-table en un archivo para su posterior uso. Este enfoque permitió al agente aprender y mejorar su estrategia en el juego de Blackjack de manera efectiva.

# %% [markdown]
# **Recompensas**
#
# ganar juego: +1
#
# perder el juego: -1
#
# juego de empate: 0
#
# Ganar el juego con blackjack natural: +1,5 (si natural es Verdadero) +1 (si natural es Falso)
#
# Fin del episodio
# El episodio termina si ocurre lo siguiente:
#
# **Terminación:**
#
# El jugador pide carta y la suma de sus manos supera 21.
#
# El jugador se pega.
#
# Un as siempre se considerará utilizable (11) a menos que haga pasar al jugador.

# %% [markdown]
# ## Entrenamiento del modelo

# %%
import gymnasium as gym
import numpy as np
import pickle
import matplotlib.pyplot as plt

# Inicializar el entorno
env = gym.make("Blackjack-v1", natural=False)

# Parámetros de Q-learning
alpha = 0.01     # Tasa de aprendizaje
gamma = 0.002    # Factor de descuento
epsilon = 0.1   # Tasa de exploración

# Inicializar Q-table con ceros para cada combinación posible de estado y acción
q_table = {}

for player_sum in range(4, 22):   
    for dealer_card in range(1, 11):
        for usable_ace in [0, 1]:
            q_table[(player_sum, dealer_card, usable_ace)] = [0, 0]  # Palo, Golpear

#(ε-greedy)
# Definir la política de acción (ε-greedy)
def choose_action(state, training=True):
    if training and np.random.rand() < epsilon:   #En este caso usamos EXPLORACIÖN
        return env.action_space.sample()          
    else:
        return np.argmax(q_table[state])          #En este caso usamos EXPLOTACIÓN

# Lista para registrar las recompensas por episodio
rewards_per_episode = []

# Entrenar el agente con Q-learning
for episode in range(100000):
    state, info = env.reset()
    done = False
    total_reward = 0
    
    while not done:
        player_sum, dealer_card, usable_ace = state
        action = choose_action(state)

        # Tomar el paso en el entorno y recibir el nuevo estado y recompensa
        next_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated

        # Actualizar Q-table usando la ecuación de Q-learning
        if not done:
            next_action = np.argmax(q_table[next_state])
            # Actualizar Q-table usando la ecuación de Bellman
            q_table[state][action] = q_table[state][action] + alpha * (
                reward + gamma * q_table[next_state][next_action] - q_table[state][action]
            )
        else:
            # Si el episodio terminó, no hay siguiente estado; solo usar la recompensa
            q_table[state][action] = q_table[state][action] + alpha * (reward - q_table[state][action])

        # Acumular la recompensa
        total_reward += reward
        state = next_state

    # Guardar la recompensa total del episodio
    rewards_per_episode.append(total_reward)



# Guardar la Q-table en un archivo
with open("q_table_blackjack1001.pkl", "wb") as file:
    pickle.dump(q_table, file)

# Suavizar la recompensa usando un promedio móvil para mejorar la visualización
window_size = 100
smoothed_rewards = np.convolve(rewards_per_episode, np.ones(window_size) / window_size, mode='valid')

# Graficar las recompensas suavizadas por episodio
plt.plot(smoothed_rewards)
plt.xlabel('Episodios')
plt.ylabel('Recompensa Promedio (Promedio móvil)')
plt.title('Progreso del Aprendizaje del Agente en Blackjack')
plt.show()


#Proceso de decisión de markov

# %% [markdown]
# ## Q-table
# Valores de acciones para cada estado

# %%
# Imprimir la Q-table
for state, actions in q_table.items():
    print(f"Estado {state}: Quedarse con las cartas={actions[0]:.2f}, Tomar una carta={actions[1]:.2f}")
# Out:
# Estado (4, 1, 0): Quedarse con las cartas=-0.05, Tomar una carta=-0.00
# Estado (4, 1, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (4, 2, 0): Quedarse con las cartas=-0.00, Tomar una carta=-0.00
# Estado (4, 2, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (4, 3, 0): Quedarse con las cartas=-0.01, Tomar una carta=-0.00
# Estado (4, 3, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (4, 4, 0): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (4, 4, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (4, 5, 0): Quedarse con las cartas=-0.02, Tomar una carta=-0.00
# Estado (4, 5, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (4, 6, 0): Quedarse con las cartas=-0.01, Tomar una carta=-0.00
# Estado (4, 6, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (4, 7, 0): Quedarse con las cartas=-0.00, Tomar una carta=-0.00
# Estado (4, 7, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (4, 8, 0): Quedarse con las cartas=-0.01, Tomar una carta=-0.00
# Estado (4, 8, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (4, 9, 0): Quedarse con las cartas=-0.06, Tomar una carta=-0.00
# Estado (4, 9, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (4, 10, 0): Quedarse con las cartas=-0.04, Tomar una carta=-0.00
# Estado (4, 10, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (5, 1, 0): Quedarse con las cartas=-0.02, Tomar una carta=-0.00
# Estado (5, 1, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (5, 2, 0): Quedarse con las cartas=-0.02, Tomar una carta=-0.00
# Estado (5, 2, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (5, 3, 0): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (5, 3, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (5, 4, 0): Quedarse con las cartas=-0.02, Tomar una carta=-0.00
# Estado (5, 4, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (5, 5, 0): Quedarse con las cartas=-0.04, Tomar una carta=-0.00
# Estado (5, 5, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (5, 6, 0): Quedarse con las cartas=-0.00, Tomar una carta=-0.00
# Estado (5, 6, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (5, 7, 0): Quedarse con las cartas=-0.00, Tomar una carta=-0.00
# Estado (5, 7, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (5, 8, 0): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (5, 8, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (5, 9, 0): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (5, 9, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (5, 10, 0): Quedarse con las cartas=-0.05, Tomar una carta=-0.00
# Estado (5, 10, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (6, 1, 0): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (6, 1, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (6, 2, 0): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (6, 2, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (6, 3, 0): Quedarse con las cartas=-0.01, Tomar una carta=-0.00
# Estado (6, 3, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (6, 4, 0): Quedarse con las cartas=-0.07, Tomar una carta=-0.00
# Estado (6, 4, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (6, 5, 0): Quedarse con las cartas=-0.05, Tomar una carta=-0.00
# Estado (6, 5, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (6, 6, 0): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (6, 6, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (6, 7, 0): Quedarse con las cartas=-0.05, Tomar una carta=-0.00
# Estado (6, 7, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (6, 8, 0): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (6, 8, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (6, 9, 0): Quedarse con las cartas=-0.02, Tomar una carta=-0.00
# Estado (6, 9, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (6, 10, 0): Quedarse con las cartas=-0.14, Tomar una carta=-0.00
# Estado (6, 10, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (7, 1, 0): Quedarse con las cartas=-0.06, Tomar una carta=-0.00
# Estado (7, 1, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (7, 2, 0): Quedarse con las cartas=-0.07, Tomar una carta=-0.00
# Estado (7, 2, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (7, 3, 0): Quedarse con las cartas=-0.01, Tomar una carta=-0.00
# Estado (7, 3, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (7, 4, 0): Quedarse con las cartas=-0.04, Tomar una carta=-0.00
# Estado (7, 4, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (7, 5, 0): Quedarse con las cartas=-0.10, Tomar una carta=-0.00
# Estado (7, 5, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (7, 6, 0): Quedarse con las cartas=-0.02, Tomar una carta=-0.00
# Estado (7, 6, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (7, 7, 0): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (7, 7, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (7, 8, 0): Quedarse con las cartas=-0.05, Tomar una carta=-0.00
# Estado (7, 8, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (7, 9, 0): Quedarse con las cartas=-0.11, Tomar una carta=-0.00
# Estado (7, 9, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (7, 10, 0): Quedarse con las cartas=-0.19, Tomar una carta=-0.00
# Estado (7, 10, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (8, 1, 0): Quedarse con las cartas=-0.09, Tomar una carta=-0.00
# Estado (8, 1, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (8, 2, 0): Quedarse con las cartas=-0.09, Tomar una carta=-0.00
# Estado (8, 2, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (8, 3, 0): Quedarse con las cartas=-0.00, Tomar una carta=-0.00
# Estado (8, 3, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (8, 4, 0): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (8, 4, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (8, 5, 0): Quedarse con las cartas=-0.04, Tomar una carta=0.00
# Estado (8, 5, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (8, 6, 0): Quedarse con las cartas=-0.03, Tomar una carta=0.00
# Estado (8, 6, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (8, 7, 0): Quedarse con las cartas=-0.06, Tomar una carta=-0.00
# Estado (8, 7, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (8, 8, 0): Quedarse con las cartas=-0.09, Tomar una carta=-0.00
# Estado (8, 8, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (8, 9, 0): Quedarse con las cartas=-0.05, Tomar una carta=-0.00
# Estado (8, 9, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (8, 10, 0): Quedarse con las cartas=-0.15, Tomar una carta=-0.00
# Estado (8, 10, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (9, 1, 0): Quedarse con las cartas=-0.09, Tomar una carta=-0.00
# Estado (9, 1, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (9, 2, 0): Quedarse con las cartas=-0.11, Tomar una carta=0.00
# Estado (9, 2, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (9, 3, 0): Quedarse con las cartas=-0.05, Tomar una carta=0.00
# Estado (9, 3, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (9, 4, 0): Quedarse con las cartas=-0.05, Tomar una carta=0.00
# Estado (9, 4, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (9, 5, 0): Quedarse con las cartas=-0.10, Tomar una carta=0.00
# Estado (9, 5, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (9, 6, 0): Quedarse con las cartas=-0.04, Tomar una carta=0.00
# Estado (9, 6, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (9, 7, 0): Quedarse con las cartas=-0.05, Tomar una carta=0.00
# Estado (9, 7, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (9, 8, 0): Quedarse con las cartas=-0.06, Tomar una carta=0.00
# Estado (9, 8, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (9, 9, 0): Quedarse con las cartas=-0.12, Tomar una carta=-0.00
# Estado (9, 9, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (9, 10, 0): Quedarse con las cartas=-0.35, Tomar una carta=-0.00
# Estado (9, 10, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (10, 1, 0): Quedarse con las cartas=-0.13, Tomar una carta=-0.00
# Estado (10, 1, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (10, 2, 0): Quedarse con las cartas=-0.03, Tomar una carta=0.00
# Estado (10, 2, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (10, 3, 0): Quedarse con las cartas=-0.04, Tomar una carta=0.00
# Estado (10, 3, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (10, 4, 0): Quedarse con las cartas=-0.12, Tomar una carta=0.00
# Estado (10, 4, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (10, 5, 0): Quedarse con las cartas=-0.08, Tomar una carta=0.00
# Estado (10, 5, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (10, 6, 0): Quedarse con las cartas=-0.03, Tomar una carta=0.00
# Estado (10, 6, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (10, 7, 0): Quedarse con las cartas=-0.10, Tomar una carta=0.00
# Estado (10, 7, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (10, 8, 0): Quedarse con las cartas=-0.08, Tomar una carta=0.00
# Estado (10, 8, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (10, 9, 0): Quedarse con las cartas=-0.12, Tomar una carta=0.00
# Estado (10, 9, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (10, 10, 0): Quedarse con las cartas=-0.30, Tomar una carta=-0.00
# Estado (10, 10, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (11, 1, 0): Quedarse con las cartas=-0.19, Tomar una carta=-0.00
# Estado (11, 1, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (11, 2, 0): Quedarse con las cartas=-0.13, Tomar una carta=0.00
# Estado (11, 2, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (11, 3, 0): Quedarse con las cartas=-0.03, Tomar una carta=0.00
# Estado (11, 3, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (11, 4, 0): Quedarse con las cartas=-0.05, Tomar una carta=0.00
# Estado (11, 4, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (11, 5, 0): Quedarse con las cartas=-0.03, Tomar una carta=0.00
# Estado (11, 5, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (11, 6, 0): Quedarse con las cartas=-0.05, Tomar una carta=0.00
# Estado (11, 6, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (11, 7, 0): Quedarse con las cartas=-0.14, Tomar una carta=0.00
# Estado (11, 7, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (11, 8, 0): Quedarse con las cartas=-0.19, Tomar una carta=0.00
# Estado (11, 8, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (11, 9, 0): Quedarse con las cartas=-0.13, Tomar una carta=0.00
# Estado (11, 9, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (11, 10, 0): Quedarse con las cartas=-0.33, Tomar una carta=0.00
# Estado (11, 10, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (12, 1, 0): Quedarse con las cartas=-0.43, Tomar una carta=-0.26
# Estado (12, 1, 1): Quedarse con las cartas=-0.04, Tomar una carta=-0.00
# Estado (12, 2, 0): Quedarse con las cartas=-0.31, Tomar una carta=-0.36
# Estado (12, 2, 1): Quedarse con las cartas=-0.02, Tomar una carta=0.00
# Estado (12, 3, 0): Quedarse con las cartas=-0.30, Tomar una carta=-0.34
# Estado (12, 3, 1): Quedarse con las cartas=-0.03, Tomar una carta=0.00
# Estado (12, 4, 0): Quedarse con las cartas=-0.14, Tomar una carta=-0.32
# Estado (12, 4, 1): Quedarse con las cartas=-0.01, Tomar una carta=0.00
# Estado (12, 5, 0): Quedarse con las cartas=-0.16, Tomar una carta=-0.25
# Estado (12, 5, 1): Quedarse con las cartas=0.00, Tomar una carta=0.00
# Estado (12, 6, 0): Quedarse con las cartas=-0.14, Tomar una carta=-0.26
# Estado (12, 6, 1): Quedarse con las cartas=-0.01, Tomar una carta=0.00
# Estado (12, 7, 0): Quedarse con las cartas=-0.38, Tomar una carta=-0.24
# Estado (12, 7, 1): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (12, 8, 0): Quedarse con las cartas=-0.41, Tomar una carta=-0.33
# Estado (12, 8, 1): Quedarse con las cartas=-0.03, Tomar una carta=0.00
# Estado (12, 9, 0): Quedarse con las cartas=-0.46, Tomar una carta=-0.31
# Estado (12, 9, 1): Quedarse con las cartas=-0.05, Tomar una carta=0.00
# Estado (12, 10, 0): Quedarse con las cartas=-0.51, Tomar una carta=-0.30
# Estado (12, 10, 1): Quedarse con las cartas=-0.05, Tomar una carta=-0.00
# Estado (13, 1, 0): Quedarse con las cartas=-0.51, Tomar una carta=-0.35
# Estado (13, 1, 1): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (13, 2, 0): Quedarse con las cartas=-0.34, Tomar una carta=-0.32
# Estado (13, 2, 1): Quedarse con las cartas=-0.01, Tomar una carta=0.00
# Estado (13, 3, 0): Quedarse con las cartas=-0.30, Tomar una carta=-0.35
# Estado (13, 3, 1): Quedarse con las cartas=-0.01, Tomar una carta=-0.00
# Estado (13, 4, 0): Quedarse con las cartas=-0.13, Tomar una carta=-0.30
# Estado (13, 4, 1): Quedarse con las cartas=-0.04, Tomar una carta=0.00
# Estado (13, 5, 0): Quedarse con las cartas=-0.04, Tomar una carta=-0.30
# Estado (13, 5, 1): Quedarse con las cartas=-0.09, Tomar una carta=0.00
# Estado (13, 6, 0): Quedarse con las cartas=-0.34, Tomar una carta=-0.38
# Estado (13, 6, 1): Quedarse con las cartas=-0.00, Tomar una carta=0.00
# Estado (13, 7, 0): Quedarse con las cartas=-0.45, Tomar una carta=-0.43
# Estado (13, 7, 1): Quedarse con las cartas=-0.03, Tomar una carta=0.00
# Estado (13, 8, 0): Quedarse con las cartas=-0.47, Tomar una carta=-0.41
# Estado (13, 8, 1): Quedarse con las cartas=-0.05, Tomar una carta=0.00
# Estado (13, 9, 0): Quedarse con las cartas=-0.49, Tomar una carta=-0.37
# Estado (13, 9, 1): Quedarse con las cartas=-0.02, Tomar una carta=0.00
# Estado (13, 10, 0): Quedarse con las cartas=-0.54, Tomar una carta=-0.37
# Estado (13, 10, 1): Quedarse con las cartas=-0.14, Tomar una carta=0.00
# Estado (14, 1, 0): Quedarse con las cartas=-0.55, Tomar una carta=-0.49
# Estado (14, 1, 1): Quedarse con las cartas=-0.05, Tomar una carta=-0.00
# Estado (14, 2, 0): Quedarse con las cartas=-0.28, Tomar una carta=-0.38
# Estado (14, 2, 1): Quedarse con las cartas=-0.02, Tomar una carta=0.00
# Estado (14, 3, 0): Quedarse con las cartas=-0.24, Tomar una carta=-0.40
# Estado (14, 3, 1): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (14, 4, 0): Quedarse con las cartas=-0.22, Tomar una carta=-0.35
# Estado (14, 4, 1): Quedarse con las cartas=-0.00, Tomar una carta=0.00
# Estado (14, 5, 0): Quedarse con las cartas=-0.23, Tomar una carta=-0.30
# Estado (14, 5, 1): Quedarse con las cartas=-0.05, Tomar una carta=0.00
# Estado (14, 6, 0): Quedarse con las cartas=0.04, Tomar una carta=-0.36
# Estado (14, 6, 1): Quedarse con las cartas=-0.00, Tomar una carta=0.00
# Estado (14, 7, 0): Quedarse con las cartas=-0.50, Tomar una carta=-0.47
# Estado (14, 7, 1): Quedarse con las cartas=-0.04, Tomar una carta=-0.00
# Estado (14, 8, 0): Quedarse con las cartas=-0.49, Tomar una carta=-0.43
# Estado (14, 8, 1): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (14, 9, 0): Quedarse con las cartas=-0.50, Tomar una carta=-0.54
# Estado (14, 9, 1): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (14, 10, 0): Quedarse con las cartas=-0.56, Tomar una carta=-0.42
# Estado (14, 10, 1): Quedarse con las cartas=-0.15, Tomar una carta=-0.00
# Estado (15, 1, 0): Quedarse con las cartas=-0.67, Tomar una carta=-0.50
# Estado (15, 1, 1): Quedarse con las cartas=-0.05, Tomar una carta=-0.00
# Estado (15, 2, 0): Quedarse con las cartas=-0.38, Tomar una carta=-0.39
# Estado (15, 2, 1): Quedarse con las cartas=-0.06, Tomar una carta=0.00
# Estado (15, 3, 0): Quedarse con las cartas=-0.16, Tomar una carta=-0.40
# Estado (15, 3, 1): Quedarse con las cartas=-0.01, Tomar una carta=-0.00
# Estado (15, 4, 0): Quedarse con las cartas=-0.16, Tomar una carta=-0.35
# Estado (15, 4, 1): Quedarse con las cartas=-0.06, Tomar una carta=-0.00
# Estado (15, 5, 0): Quedarse con las cartas=-0.15, Tomar una carta=-0.29
# Estado (15, 5, 1): Quedarse con las cartas=-0.03, Tomar una carta=0.00
# Estado (15, 6, 0): Quedarse con las cartas=-0.10, Tomar una carta=-0.34
# Estado (15, 6, 1): Quedarse con las cartas=-0.01, Tomar una carta=0.00
# Estado (15, 7, 0): Quedarse con las cartas=-0.43, Tomar una carta=-0.56
# Estado (15, 7, 1): Quedarse con las cartas=-0.02, Tomar una carta=-0.00
# Estado (15, 8, 0): Quedarse con las cartas=-0.57, Tomar una carta=-0.48
# Estado (15, 8, 1): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (15, 9, 0): Quedarse con las cartas=-0.59, Tomar una carta=-0.57
# Estado (15, 9, 1): Quedarse con las cartas=-0.04, Tomar una carta=-0.00
# Estado (15, 10, 0): Quedarse con las cartas=-0.70, Tomar una carta=-0.45
# Estado (15, 10, 1): Quedarse con las cartas=-0.15, Tomar una carta=-0.00
# Estado (16, 1, 0): Quedarse con las cartas=-0.70, Tomar una carta=-0.58
# Estado (16, 1, 1): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (16, 2, 0): Quedarse con las cartas=-0.26, Tomar una carta=-0.46
# Estado (16, 2, 1): Quedarse con las cartas=-0.01, Tomar una carta=0.00
# Estado (16, 3, 0): Quedarse con las cartas=-0.24, Tomar una carta=-0.36
# Estado (16, 3, 1): Quedarse con las cartas=-0.02, Tomar una carta=0.00
# Estado (16, 4, 0): Quedarse con las cartas=-0.28, Tomar una carta=-0.41
# Estado (16, 4, 1): Quedarse con las cartas=-0.04, Tomar una carta=0.00
# Estado (16, 5, 0): Quedarse con las cartas=-0.16, Tomar una carta=-0.33
# Estado (16, 5, 1): Quedarse con las cartas=-0.06, Tomar una carta=0.00
# Estado (16, 6, 0): Quedarse con las cartas=-0.20, Tomar una carta=-0.33
# Estado (16, 6, 1): Quedarse con las cartas=-0.02, Tomar una carta=0.00
# Estado (16, 7, 0): Quedarse con las cartas=-0.54, Tomar una carta=-0.60
# Estado (16, 7, 1): Quedarse con las cartas=-0.04, Tomar una carta=-0.00
# Estado (16, 8, 0): Quedarse con las cartas=-0.63, Tomar una carta=-0.59
# Estado (16, 8, 1): Quedarse con las cartas=-0.04, Tomar una carta=-0.00
# Estado (16, 9, 0): Quedarse con las cartas=-0.51, Tomar una carta=-0.65
# Estado (16, 9, 1): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (16, 10, 0): Quedarse con las cartas=-0.53, Tomar una carta=-0.66
# Estado (16, 10, 1): Quedarse con las cartas=-0.15, Tomar una carta=-0.00
# Estado (17, 1, 0): Quedarse con las cartas=-0.66, Tomar una carta=-0.69
# Estado (17, 1, 1): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (17, 2, 0): Quedarse con las cartas=-0.20, Tomar una carta=-0.36
# Estado (17, 2, 1): Quedarse con las cartas=-0.05, Tomar una carta=-0.00
# Estado (17, 3, 0): Quedarse con las cartas=-0.16, Tomar una carta=-0.32
# Estado (17, 3, 1): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (17, 4, 0): Quedarse con las cartas=0.02, Tomar una carta=-0.28
# Estado (17, 4, 1): Quedarse con las cartas=-0.01, Tomar una carta=0.00
# Estado (17, 5, 0): Quedarse con las cartas=-0.04, Tomar una carta=-0.20
# Estado (17, 5, 1): Quedarse con las cartas=-0.01, Tomar una carta=0.00
# Estado (17, 6, 0): Quedarse con las cartas=0.10, Tomar una carta=-0.33
# Estado (17, 6, 1): Quedarse con las cartas=-0.01, Tomar una carta=0.00
# Estado (17, 7, 0): Quedarse con las cartas=-0.17, Tomar una carta=-0.30
# Estado (17, 7, 1): Quedarse con las cartas=-0.06, Tomar una carta=-0.00
# Estado (17, 8, 0): Quedarse con las cartas=-0.37, Tomar una carta=-0.44
# Estado (17, 8, 1): Quedarse con las cartas=-0.04, Tomar una carta=-0.00
# Estado (17, 9, 0): Quedarse con las cartas=-0.44, Tomar una carta=-0.52
# Estado (17, 9, 1): Quedarse con las cartas=-0.03, Tomar una carta=-0.00
# Estado (17, 10, 0): Quedarse con las cartas=-0.42, Tomar una carta=-0.68
# Estado (17, 10, 1): Quedarse con las cartas=-0.13, Tomar una carta=-0.00
# Estado (18, 1, 0): Quedarse con las cartas=-0.28, Tomar una carta=-0.52
# Estado (18, 1, 1): Quedarse con las cartas=-0.04, Tomar una carta=-0.00
# Estado (18, 2, 0): Quedarse con las cartas=0.13, Tomar una carta=-0.25
# Estado (18, 2, 1): Quedarse con las cartas=-0.05, Tomar una carta=0.00
# Estado (18, 3, 0): Quedarse con las cartas=0.07, Tomar una carta=-0.20
# Estado (18, 3, 1): Quedarse con las cartas=-0.04, Tomar una carta=0.00
# Estado (18, 4, 0): Quedarse con las cartas=0.29, Tomar una carta=-0.21
# Estado (18, 4, 1): Quedarse con las cartas=0.21, Tomar una carta=-0.00
# Estado (18, 5, 0): Quedarse con las cartas=0.17, Tomar una carta=-0.23
# Estado (18, 5, 1): Quedarse con las cartas=0.28, Tomar una carta=0.00
# Estado (18, 6, 0): Quedarse con las cartas=0.25, Tomar una carta=-0.27
# Estado (18, 6, 1): Quedarse con las cartas=-0.00, Tomar una carta=0.00
# Estado (18, 7, 0): Quedarse con las cartas=0.42, Tomar una carta=-0.22
# Estado (18, 7, 1): Quedarse con las cartas=0.36, Tomar una carta=-0.00
# Estado (18, 8, 0): Quedarse con las cartas=0.20, Tomar una carta=-0.28
# Estado (18, 8, 1): Quedarse con las cartas=-0.01, Tomar una carta=-0.00
# Estado (18, 9, 0): Quedarse con las cartas=-0.26, Tomar una carta=-0.42
# Estado (18, 9, 1): Quedarse con las cartas=-0.05, Tomar una carta=-0.00
# Estado (18, 10, 0): Quedarse con las cartas=-0.27, Tomar una carta=-0.74
# Estado (18, 10, 1): Quedarse con las cartas=-0.10, Tomar una carta=-0.00
# Estado (19, 1, 0): Quedarse con las cartas=-0.08, Tomar una carta=-0.40
# Estado (19, 1, 1): Quedarse con las cartas=-0.01, Tomar una carta=-0.00
# Estado (19, 2, 0): Quedarse con las cartas=0.47, Tomar una carta=-0.20
# Estado (19, 2, 1): Quedarse con las cartas=0.37, Tomar una carta=-0.00
# Estado (19, 3, 0): Quedarse con las cartas=0.45, Tomar una carta=-0.21
# Estado (19, 3, 1): Quedarse con las cartas=0.27, Tomar una carta=0.00
# Estado (19, 4, 0): Quedarse con las cartas=0.44, Tomar una carta=-0.19
# Estado (19, 4, 1): Quedarse con las cartas=0.25, Tomar una carta=0.00
# Estado (19, 5, 0): Quedarse con las cartas=0.40, Tomar una carta=-0.22
# Estado (19, 5, 1): Quedarse con las cartas=0.37, Tomar una carta=0.00
# Estado (19, 6, 0): Quedarse con las cartas=0.55, Tomar una carta=-0.26
# Estado (19, 6, 1): Quedarse con las cartas=0.43, Tomar una carta=0.00
# Estado (19, 7, 0): Quedarse con las cartas=0.53, Tomar una carta=-0.21
# Estado (19, 7, 1): Quedarse con las cartas=0.50, Tomar una carta=0.00
# Estado (19, 8, 0): Quedarse con las cartas=0.56, Tomar una carta=-0.21
# Estado (19, 8, 1): Quedarse con las cartas=0.49, Tomar una carta=-0.00
# Estado (19, 9, 0): Quedarse con las cartas=0.28, Tomar una carta=-0.29
# Estado (19, 9, 1): Quedarse con las cartas=0.23, Tomar una carta=-0.00
# Estado (19, 10, 0): Quedarse con las cartas=-0.07, Tomar una carta=-0.66
# Estado (19, 10, 1): Quedarse con las cartas=-0.01, Tomar una carta=-0.00
# Estado (20, 1, 0): Quedarse con las cartas=0.07, Tomar una carta=-0.46
# Estado (20, 1, 1): Quedarse con las cartas=-0.00, Tomar una carta=-0.00
# Estado (20, 2, 0): Quedarse con las cartas=0.64, Tomar una carta=-0.37
# Estado (20, 2, 1): Quedarse con las cartas=0.62, Tomar una carta=0.00
# Estado (20, 3, 0): Quedarse con las cartas=0.69, Tomar una carta=-0.43
# Estado (20, 3, 1): Quedarse con las cartas=0.48, Tomar una carta=0.00
# Estado (20, 4, 0): Quedarse con las cartas=0.72, Tomar una carta=-0.30
# Estado (20, 4, 1): Quedarse con las cartas=0.58, Tomar una carta=0.00
# Estado (20, 5, 0): Quedarse con las cartas=0.72, Tomar una carta=-0.34
# Estado (20, 5, 1): Quedarse con las cartas=0.55, Tomar una carta=0.00
# Estado (20, 6, 0): Quedarse con las cartas=0.62, Tomar una carta=-0.40
# Estado (20, 6, 1): Quedarse con las cartas=0.54, Tomar una carta=-0.00
# Estado (20, 7, 0): Quedarse con las cartas=0.76, Tomar una carta=-0.43
# Estado (20, 7, 1): Quedarse con las cartas=0.53, Tomar una carta=-0.00
# Estado (20, 8, 0): Quedarse con las cartas=0.77, Tomar una carta=-0.25
# Estado (20, 8, 1): Quedarse con las cartas=0.64, Tomar una carta=0.00
# Estado (20, 9, 0): Quedarse con las cartas=0.77, Tomar una carta=-0.41
# Estado (20, 9, 1): Quedarse con las cartas=0.66, Tomar una carta=0.00
# Estado (20, 10, 0): Quedarse con las cartas=0.38, Tomar una carta=-0.84
# Estado (20, 10, 1): Quedarse con las cartas=0.57, Tomar una carta=-0.00
# Estado (21, 1, 0): Quedarse con las cartas=0.62, Tomar una carta=-0.25
# Estado (21, 1, 1): Quedarse con las cartas=0.66, Tomar una carta=0.00
# Estado (21, 2, 0): Quedarse con las cartas=0.80, Tomar una carta=-0.06
# Estado (21, 2, 1): Quedarse con las cartas=0.97, Tomar una carta=0.00
# Estado (21, 3, 0): Quedarse con las cartas=0.79, Tomar una carta=-0.08
# Estado (21, 3, 1): Quedarse con las cartas=0.97, Tomar una carta=0.00
# Estado (21, 4, 0): Quedarse con las cartas=0.75, Tomar una carta=-0.11
# Estado (21, 4, 1): Quedarse con las cartas=0.97, Tomar una carta=0.00
# Estado (21, 5, 0): Quedarse con las cartas=0.73, Tomar una carta=-0.10
# Estado (21, 5, 1): Quedarse con las cartas=0.95, Tomar una carta=0.00
# Estado (21, 6, 0): Quedarse con las cartas=0.75, Tomar una carta=-0.08
# Estado (21, 6, 1): Quedarse con las cartas=0.97, Tomar una carta=0.00
# Estado (21, 7, 0): Quedarse con las cartas=0.90, Tomar una carta=-0.17
# Estado (21, 7, 1): Quedarse con las cartas=0.98, Tomar una carta=0.00
# Estado (21, 8, 0): Quedarse con las cartas=0.92, Tomar una carta=-0.17
# Estado (21, 8, 1): Quedarse con las cartas=0.96, Tomar una carta=0.00
# Estado (21, 9, 0): Quedarse con las cartas=0.95, Tomar una carta=-0.11
# Estado (21, 9, 1): Quedarse con las cartas=0.98, Tomar una carta=0.00
# Estado (21, 10, 0): Quedarse con las cartas=0.87, Tomar una carta=-0.54
# Estado (21, 10, 1): Quedarse con las cartas=0.92, Tomar una carta=0.00

# %% [markdown]
# ## Prueba del modelo con EXPLOTACION

# %%
# Prueba del agente después de entrenar usando la Q-table guardada
def test_agent(num_episodes=1000):  # Reducimos el número de episodios para hacer el resultado más legible
    wins, losses, draws = 0, 0, 0
    
    # Cargar la Q-table guardada
    with open("q_table_blackjack1001.pkl", "rb") as file:
        q_table = pickle.load(file)
    
    # Jugar con el agente entrenado
    for episode in range(num_episodes):
        state, info = env.reset()
        done = False
        episode_steps = []  # Lista para almacenar el historial de jugadas del episodio
        final_player_sum = None
        
        print(f"\n--- Episodio {episode + 1} ---")
        
        while not done:
            # Obtener la acción de la Q-table
            action = np.argmax(q_table[state])  # Seleccionar la mejor acción según la Q-table
            
            # Registrar el estado actual y la acción
            player_sum, dealer_card, usable_ace = state
            action_name = "Pedir carta" if action == 1 else "No quiero una carta"
            episode_steps.append({
                "Jugador": player_sum,
                "Carta Crupier": dealer_card,
                "As Utilizable": usable_ace,
                "Acción": action_name
            })
            
            # Si el jugador elige "palo", guardamos la suma final del jugador
            if action == 0:  # Si elige "Palo"
                final_player_sum = player_sum
            
            # Realizar la acción
            next_state, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated
            state = next_state

        # Resultado final del episodio
        if reward == 1:
            wins += 1
            outcome = "Ganó"
        elif reward == -1:
            losses += 1
            outcome = "Perdió"
        else:
            draws += 1
            outcome = "Empató"
        
        # Mostrar el historial del episodio
        print(f"Resultado: {outcome}")
        for step, details in enumerate(episode_steps):
            print(f"Jugada {step + 1}: Jugador={details['Jugador']}, "
                  f"Carta Crupier={details['Carta Crupier']}, "
                  f"As Utilizable={details['As Utilizable']}, "
                  f"Acción={details['Acción']}")
        
        # Mostrar el puntaje final del jugador
        print(f"Jugador terminó con: {final_player_sum}")
    
    print(f"\nResultados tras {num_episodes} episodios:")
    print(f"Victorias: {wins}")
    print(f"Derrotas: {losses}")
    print(f"Empates: {draws}")
    print(f"Total ganadas: {wins}")
    print(f"Total perdidas: {losses}")

# Ejecutar el test del agente
test_agent()
# Out:
# --- Episodio 1 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 2 ---
# Resultado: Ganó
# Jugada 1: Jugador=12, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=21, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 3 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=10, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=10, As Utilizable=1, Acción=Pedir carta
# Jugada 3: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 4 ---
# Resultado: Ganó
# Jugada 1: Jugador=11, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=17, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 5 ---
# Resultado: Ganó
# Jugada 1: Jugador=14, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 6 ---
# Resultado: Perdió
# Jugada 1: Jugador=17, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 7 ---
# Resultado: Perdió
# Jugada 1: Jugador=17, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 8 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 9 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 12
#
# --- Episodio 10 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 12
#
# --- Episodio 11 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 12 ---
# Resultado: Perdió
# Jugada 1: Jugador=19, Carta Crupier=4, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 13 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 14 ---
# Resultado: Empató
# Jugada 1: Jugador=11, Carta Crupier=5, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=18, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 15 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 16 ---
# Resultado: Empató
# Jugada 1: Jugador=12, Carta Crupier=10, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=20, Carta Crupier=10, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 17 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 18 ---
# Resultado: Perdió
# Jugada 1: Jugador=19, Carta Crupier=4, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 19 ---
# Resultado: Ganó
# Jugada 1: Jugador=21, Carta Crupier=7, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 20 ---
# Resultado: Ganó
# Jugada 1: Jugador=14, Carta Crupier=8, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=18, Carta Crupier=8, As Utilizable=1, Acción=Pedir carta
# Jugada 3: Jugador=18, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 21 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 22 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=1, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 23 ---
# Resultado: Perdió
# Jugada 1: Jugador=6, Carta Crupier=4, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 24 ---
# Resultado: Ganó
# Jugada 1: Jugador=13, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 13
#
# --- Episodio 25 ---
# Resultado: Empató
# Jugada 1: Jugador=9, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 26 ---
# Resultado: Perdió
# Jugada 1: Jugador=11, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 27 ---
# Resultado: Ganó
# Jugada 1: Jugador=9, Carta Crupier=3, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=18, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 28 ---
# Resultado: Ganó
# Jugada 1: Jugador=17, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 29 ---
# Resultado: Ganó
# Jugada 1: Jugador=16, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 30 ---
# Resultado: Perdió
# Jugada 1: Jugador=13, Carta Crupier=1, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=1, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=17, Carta Crupier=1, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 31 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 32 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=7, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 33 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=10, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 34 ---
# Resultado: Ganó
# Jugada 1: Jugador=19, Carta Crupier=4, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 35 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 36 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 37 ---
# Resultado: Ganó
# Jugada 1: Jugador=14, Carta Crupier=2, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 38 ---
# Resultado: Ganó
# Jugada 1: Jugador=6, Carta Crupier=4, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=11, Carta Crupier=4, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=21, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 39 ---
# Resultado: Ganó
# Jugada 1: Jugador=6, Carta Crupier=6, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 40 ---
# Resultado: Ganó
# Jugada 1: Jugador=21, Carta Crupier=5, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 41 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 42 ---
# Resultado: Ganó
# Jugada 1: Jugador=21, Carta Crupier=3, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 43 ---
# Resultado: Empató
# Jugada 1: Jugador=20, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 44 ---
# Resultado: Ganó
# Jugada 1: Jugador=15, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 45 ---
# Resultado: Perdió
# Jugada 1: Jugador=13, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 46 ---
# Resultado: Ganó
# Jugada 1: Jugador=15, Carta Crupier=10, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=15, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=21, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 47 ---
# Resultado: Perdió
# Jugada 1: Jugador=9, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 48 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 49 ---
# Resultado: Ganó
# Jugada 1: Jugador=15, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 50 ---
# Resultado: Perdió
# Jugada 1: Jugador=8, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=10, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=17, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 51 ---
# Resultado: Ganó
# Jugada 1: Jugador=17, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 52 ---
# Resultado: Perdió
# Jugada 1: Jugador=18, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 53 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 54 ---
# Resultado: Empató
# Jugada 1: Jugador=12, Carta Crupier=1, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=17, Carta Crupier=1, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 55 ---
# Resultado: Ganó
# Jugada 1: Jugador=12, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 12
#
# --- Episodio 56 ---
# Resultado: Ganó
# Jugada 1: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 57 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 58 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 59 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 60 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 61 ---
# Resultado: Ganó
# Jugada 1: Jugador=12, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 12
#
# --- Episodio 62 ---
# Resultado: Ganó
# Jugada 1: Jugador=18, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 63 ---
# Resultado: Perdió
# Jugada 1: Jugador=13, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 64 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 65 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 66 ---
# Resultado: Empató
# Jugada 1: Jugador=15, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=18, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 67 ---
# Resultado: Ganó
# Jugada 1: Jugador=17, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 68 ---
# Resultado: Ganó
# Jugada 1: Jugador=4, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=12, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=17, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 69 ---
# Resultado: Perdió
# Jugada 1: Jugador=13, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 70 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=8, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 71 ---
# Resultado: Ganó
# Jugada 1: Jugador=13, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=20, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 72 ---
# Resultado: Perdió
# Jugada 1: Jugador=13, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 73 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 74 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 75 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 76 ---
# Resultado: Perdió
# Jugada 1: Jugador=17, Carta Crupier=2, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=2, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 77 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 78 ---
# Resultado: Ganó
# Jugada 1: Jugador=15, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 79 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 80 ---
# Resultado: Perdió
# Jugada 1: Jugador=10, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=12, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=16, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 81 ---
# Resultado: Empató
# Jugada 1: Jugador=20, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 82 ---
# Resultado: Perdió
# Jugada 1: Jugador=17, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 83 ---
# Resultado: Ganó
# Jugada 1: Jugador=19, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 84 ---
# Resultado: Ganó
# Jugada 1: Jugador=11, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 85 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 86 ---
# Resultado: Perdió
# Jugada 1: Jugador=10, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 87 ---
# Resultado: Ganó
# Jugada 1: Jugador=9, Carta Crupier=5, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=20, Carta Crupier=5, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 88 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=1, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 89 ---
# Resultado: Perdió
# Jugada 1: Jugador=17, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 90 ---
# Resultado: Perdió
# Jugada 1: Jugador=13, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 91 ---
# Resultado: Perdió
# Jugada 1: Jugador=19, Carta Crupier=1, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 92 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 93 ---
# Resultado: Ganó
# Jugada 1: Jugador=12, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 94 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 95 ---
# Resultado: Perdió
# Jugada 1: Jugador=8, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=10, As Utilizable=1, Acción=Pedir carta
# Jugada 3: Jugador=13, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 4: Jugador=14, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 5: Jugador=17, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 96 ---
# Resultado: Ganó
# Jugada 1: Jugador=11, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 97 ---
# Resultado: Ganó
# Jugada 1: Jugador=13, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=20, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 98 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 99 ---
# Resultado: Ganó
# Jugada 1: Jugador=8, Carta Crupier=3, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=18, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 100 ---
# Resultado: Ganó
# Jugada 1: Jugador=15, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 101 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 12
#
# --- Episodio 102 ---
# Resultado: Ganó
# Jugada 1: Jugador=21, Carta Crupier=2, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 103 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=5, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 104 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 105 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 106 ---
# Resultado: Ganó
# Jugada 1: Jugador=15, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 107 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 108 ---
# Resultado: Perdió
# Jugada 1: Jugador=9, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=12, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=15, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 109 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 110 ---
# Resultado: Ganó
# Jugada 1: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 111 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 12
#
# --- Episodio 112 ---
# Resultado: Empató
# Jugada 1: Jugador=20, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 113 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 114 ---
# Resultado: Ganó
# Jugada 1: Jugador=18, Carta Crupier=7, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 115 ---
# Resultado: Perdió
# Jugada 1: Jugador=7, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 116 ---
# Resultado: Ganó
# Jugada 1: Jugador=16, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 117 ---
# Resultado: Perdió
# Jugada 1: Jugador=9, Carta Crupier=1, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=1, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 118 ---
# Resultado: Ganó
# Jugada 1: Jugador=9, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 119 ---
# Resultado: Ganó
# Jugada 1: Jugador=17, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 120 ---
# Resultado: Empató
# Jugada 1: Jugador=18, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 121 ---
# Resultado: Ganó
# Jugada 1: Jugador=13, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 13
#
# --- Episodio 122 ---
# Resultado: Ganó
# Jugada 1: Jugador=21, Carta Crupier=8, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 123 ---
# Resultado: Perdió
# Jugada 1: Jugador=19, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 124 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 125 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 126 ---
# Resultado: Ganó
# Jugada 1: Jugador=21, Carta Crupier=4, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 127 ---
# Resultado: Ganó
# Jugada 1: Jugador=12, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 12
#
# --- Episodio 128 ---
# Resultado: Empató
# Jugada 1: Jugador=20, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 129 ---
# Resultado: Ganó
# Jugada 1: Jugador=9, Carta Crupier=4, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=20, Carta Crupier=4, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 130 ---
# Resultado: Perdió
# Jugada 1: Jugador=11, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=12, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=17, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 131 ---
# Resultado: Ganó
# Jugada 1: Jugador=13, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=19, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 132 ---
# Resultado: Perdió
# Jugada 1: Jugador=8, Carta Crupier=4, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 133 ---
# Resultado: Ganó
# Jugada 1: Jugador=19, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 134 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 135 ---
# Resultado: Perdió
# Jugada 1: Jugador=20, Carta Crupier=1, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 136 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 137 ---
# Resultado: Ganó
# Jugada 1: Jugador=12, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=17, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 138 ---
# Resultado: Perdió
# Jugada 1: Jugador=17, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 139 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=18, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 140 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 141 ---
# Resultado: Ganó
# Jugada 1: Jugador=13, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 142 ---
# Resultado: Perdió
# Jugada 1: Jugador=17, Carta Crupier=10, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=17, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 143 ---
# Resultado: Ganó
# Jugada 1: Jugador=8, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=18, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 144 ---
# Resultado: Ganó
# Jugada 1: Jugador=21, Carta Crupier=10, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 145 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 146 ---
# Resultado: Ganó
# Jugada 1: Jugador=11, Carta Crupier=3, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 147 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 148 ---
# Resultado: Ganó
# Jugada 1: Jugador=7, Carta Crupier=2, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 149 ---
# Resultado: Ganó
# Jugada 1: Jugador=14, Carta Crupier=1, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=1, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=17, Carta Crupier=1, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 150 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=3, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=17, Carta Crupier=3, As Utilizable=1, Acción=Pedir carta
# Jugada 3: Jugador=15, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 151 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 152 ---
# Resultado: Ganó
# Jugada 1: Jugador=12, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 12
#
# --- Episodio 153 ---
# Resultado: Perdió
# Jugada 1: Jugador=9, Carta Crupier=6, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 154 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 155 ---
# Resultado: Ganó
# Jugada 1: Jugador=16, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 156 ---
# Resultado: Ganó
# Jugada 1: Jugador=13, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=20, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 157 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=6, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=6, As Utilizable=1, Acción=Pedir carta
# Jugada 3: Jugador=20, Carta Crupier=6, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 158 ---
# Resultado: Ganó
# Jugada 1: Jugador=11, Carta Crupier=5, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=21, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 159 ---
# Resultado: Perdió
# Jugada 1: Jugador=7, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=17, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 160 ---
# Resultado: Perdió
# Jugada 1: Jugador=9, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 161 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 162 ---
# Resultado: Empató
# Jugada 1: Jugador=12, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 163 ---
# Resultado: Ganó
# Jugada 1: Jugador=14, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 164 ---
# Resultado: Ganó
# Jugada 1: Jugador=21, Carta Crupier=5, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 165 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=9, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 166 ---
# Resultado: Ganó
# Jugada 1: Jugador=8, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=13, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=21, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 167 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 168 ---
# Resultado: Empató
# Jugada 1: Jugador=20, Carta Crupier=1, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 169 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 170 ---
# Resultado: Ganó
# Jugada 1: Jugador=11, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=21, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 171 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 172 ---
# Resultado: Perdió
# Jugada 1: Jugador=10, Carta Crupier=5, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=12, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 12
#
# --- Episodio 173 ---
# Resultado: Ganó
# Jugada 1: Jugador=21, Carta Crupier=2, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 174 ---
# Resultado: Perdió
# Jugada 1: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 175 ---
# Resultado: Ganó
# Jugada 1: Jugador=12, Carta Crupier=10, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=20, Carta Crupier=10, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 176 ---
# Resultado: Ganó
# Jugada 1: Jugador=10, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=13, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=18, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 177 ---
# Resultado: Perdió
# Jugada 1: Jugador=8, Carta Crupier=3, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 178 ---
# Resultado: Ganó
# Jugada 1: Jugador=21, Carta Crupier=10, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 179 ---
# Resultado: Ganó
# Jugada 1: Jugador=21, Carta Crupier=10, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 180 ---
# Resultado: Perdió
# Jugada 1: Jugador=10, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 181 ---
# Resultado: Ganó
# Jugada 1: Jugador=18, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 182 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 183 ---
# Resultado: Ganó
# Jugada 1: Jugador=9, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=20, Carta Crupier=8, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 184 ---
# Resultado: Ganó
# Jugada 1: Jugador=21, Carta Crupier=2, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 185 ---
# Resultado: Ganó
# Jugada 1: Jugador=16, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 186 ---
# Resultado: Perdió
# Jugada 1: Jugador=7, Carta Crupier=3, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=17, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 187 ---
# Resultado: Perdió
# Jugada 1: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 188 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 189 ---
# Resultado: Perdió
# Jugada 1: Jugador=6, Carta Crupier=3, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=11, Carta Crupier=3, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=17, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 190 ---
# Resultado: Ganó
# Jugada 1: Jugador=18, Carta Crupier=10, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=21, Carta Crupier=10, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 191 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=17, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 192 ---
# Resultado: Ganó
# Jugada 1: Jugador=13, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=21, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 193 ---
# Resultado: Ganó
# Jugada 1: Jugador=17, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 194 ---
# Resultado: Ganó
# Jugada 1: Jugador=19, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 195 ---
# Resultado: Perdió
# Jugada 1: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 196 ---
# Resultado: Perdió
# Jugada 1: Jugador=17, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 197 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=15, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 198 ---
# Resultado: Ganó
# Jugada 1: Jugador=15, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=21, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 199 ---
# Resultado: Ganó
# Jugada 1: Jugador=12, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=21, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 200 ---
# Resultado: Ganó
# Jugada 1: Jugador=9, Carta Crupier=2, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 201 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 202 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 203 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 204 ---
# Resultado: Empató
# Jugada 1: Jugador=17, Carta Crupier=4, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=18, Carta Crupier=4, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 205 ---
# Resultado: Perdió
# Jugada 1: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 206 ---
# Resultado: Perdió
# Jugada 1: Jugador=13, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=17, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 207 ---
# Resultado: Ganó
# Jugada 1: Jugador=10, Carta Crupier=5, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 208 ---
# Resultado: Perdió
# Jugada 1: Jugador=7, Carta Crupier=5, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=17, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 209 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 210 ---
# Resultado: Perdió
# Jugada 1: Jugador=17, Carta Crupier=1, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 211 ---
# Resultado: Ganó
# Jugada 1: Jugador=6, Carta Crupier=5, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 212 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=9, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=9, As Utilizable=1, Acción=Pedir carta
# Jugada 3: Jugador=13, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 213 ---
# Resultado: Perdió
# Jugada 1: Jugador=18, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 214 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 215 ---
# Resultado: Empató
# Jugada 1: Jugador=10, Carta Crupier=1, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=1, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=19, Carta Crupier=1, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 216 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 217 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=15, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 218 ---
# Resultado: Ganó
# Jugada 1: Jugador=5, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=10, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=19, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 219 ---
# Resultado: Perdió
# Jugada 1: Jugador=18, Carta Crupier=10, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=18, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 220 ---
# Resultado: Ganó
# Jugada 1: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 221 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=1, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 222 ---
# Resultado: Perdió
# Jugada 1: Jugador=17, Carta Crupier=3, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=12, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 12
#
# --- Episodio 223 ---
# Resultado: Perdió
# Jugada 1: Jugador=19, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 224 ---
# Resultado: Ganó
# Jugada 1: Jugador=17, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 225 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 226 ---
# Resultado: Ganó
# Jugada 1: Jugador=18, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 227 ---
# Resultado: Perdió
# Jugada 1: Jugador=20, Carta Crupier=1, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 228 ---
# Resultado: Empató
# Jugada 1: Jugador=14, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=17, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 229 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 12
#
# --- Episodio 230 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 231 ---
# Resultado: Ganó
# Jugada 1: Jugador=11, Carta Crupier=5, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=21, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 232 ---
# Resultado: Ganó
# Jugada 1: Jugador=13, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 13
#
# --- Episodio 233 ---
# Resultado: Ganó
# Jugada 1: Jugador=15, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=21, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 234 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 235 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 236 ---
# Resultado: Ganó
# Jugada 1: Jugador=13, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 237 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 238 ---
# Resultado: Ganó
# Jugada 1: Jugador=11, Carta Crupier=6, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=15, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 239 ---
# Resultado: Ganó
# Jugada 1: Jugador=11, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=21, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 240 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 241 ---
# Resultado: Perdió
# Jugada 1: Jugador=13, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 242 ---
# Resultado: Empató
# Jugada 1: Jugador=20, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 243 ---
# Resultado: Perdió
# Jugada 1: Jugador=13, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 13
#
# --- Episodio 244 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=9, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=18, Carta Crupier=9, As Utilizable=1, Acción=Pedir carta
# Jugada 3: Jugador=18, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 245 ---
# Resultado: Perdió
# Jugada 1: Jugador=13, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=15, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 246 ---
# Resultado: Ganó
# Jugada 1: Jugador=12, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 12
#
# --- Episodio 247 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 248 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 249 ---
# Resultado: Empató
# Jugada 1: Jugador=8, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=18, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 250 ---
# Resultado: Ganó
# Jugada 1: Jugador=15, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 251 ---
# Resultado: Ganó
# Jugada 1: Jugador=16, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 252 ---
# Resultado: Ganó
# Jugada 1: Jugador=12, Carta Crupier=9, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=9, As Utilizable=1, Acción=Pedir carta
# Jugada 3: Jugador=19, Carta Crupier=9, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 253 ---
# Resultado: Ganó
# Jugada 1: Jugador=14, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 254 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 255 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 256 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 257 ---
# Resultado: Perdió
# Jugada 1: Jugador=18, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 258 ---
# Resultado: Ganó
# Jugada 1: Jugador=15, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=18, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 259 ---
# Resultado: Ganó
# Jugada 1: Jugador=15, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 260 ---
# Resultado: Perdió
# Jugada 1: Jugador=13, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 13
#
# --- Episodio 261 ---
# Resultado: Empató
# Jugada 1: Jugador=20, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 262 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 263 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=1, As Utilizable=0, Acción=Pedir carta
# ...
# Jugada 1: Jugador=12, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=13, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 913 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 914 ---
# Resultado: Perdió
# Jugada 1: Jugador=20, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 915 ---
# Resultado: Perdió
# Jugada 1: Jugador=5, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=15, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=17, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 916 ---
# Resultado: Ganó
# Jugada 1: Jugador=16, Carta Crupier=10, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=13, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=21, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 917 ---
# Resultado: Ganó
# Jugada 1: Jugador=12, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 918 ---
# Resultado: Ganó
# Jugada 1: Jugador=21, Carta Crupier=10, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 919 ---
# Resultado: Perdió
# Jugada 1: Jugador=17, Carta Crupier=1, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 920 ---
# Resultado: Perdió
# Jugada 1: Jugador=20, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 921 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 922 ---
# Resultado: Ganó
# Jugada 1: Jugador=11, Carta Crupier=5, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 923 ---
# Resultado: Empató
# Jugada 1: Jugador=20, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 924 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 925 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 926 ---
# Resultado: Perdió
# Jugada 1: Jugador=13, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 13
#
# --- Episodio 927 ---
# Resultado: Ganó
# Jugada 1: Jugador=15, Carta Crupier=1, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=20, Carta Crupier=1, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 928 ---
# Resultado: Empató
# Jugada 1: Jugador=16, Carta Crupier=8, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=18, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 929 ---
# Resultado: Ganó
# Jugada 1: Jugador=18, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 930 ---
# Resultado: Perdió
# Jugada 1: Jugador=17, Carta Crupier=1, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 931 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 12
#
# --- Episodio 932 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 933 ---
# Resultado: Perdió
# Jugada 1: Jugador=13, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 934 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=18, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 935 ---
# Resultado: Ganó
# Jugada 1: Jugador=15, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 936 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 937 ---
# Resultado: Empató
# Jugada 1: Jugador=11, Carta Crupier=3, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=21, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 938 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 939 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 940 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 941 ---
# Resultado: Empató
# Jugada 1: Jugador=12, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=17, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 942 ---
# Resultado: Ganó
# Jugada 1: Jugador=8, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=12, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=18, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 943 ---
# Resultado: Perdió
# Jugada 1: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 944 ---
# Resultado: Ganó
# Jugada 1: Jugador=18, Carta Crupier=6, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=18, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 945 ---
# Resultado: Perdió
# Jugada 1: Jugador=8, Carta Crupier=4, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=18, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 946 ---
# Resultado: Perdió
# Jugada 1: Jugador=20, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 947 ---
# Resultado: Perdió
# Jugada 1: Jugador=8, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 948 ---
# Resultado: Perdió
# Jugada 1: Jugador=9, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=14, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 949 ---
# Resultado: Ganó
# Jugada 1: Jugador=11, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=21, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 950 ---
# Resultado: Ganó
# Jugada 1: Jugador=18, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 951 ---
# Resultado: Perdió
# Jugada 1: Jugador=13, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 13
#
# --- Episodio 952 ---
# Resultado: Ganó
# Jugada 1: Jugador=13, Carta Crupier=8, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=20, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 953 ---
# Resultado: Ganó
# Jugada 1: Jugador=16, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 954 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 955 ---
# Resultado: Ganó
# Jugada 1: Jugador=11, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 956 ---
# Resultado: Ganó
# Jugada 1: Jugador=19, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 957 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 958 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 959 ---
# Resultado: Perdió
# Jugada 1: Jugador=18, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 960 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 961 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=1, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=1, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 962 ---
# Resultado: Perdió
# Jugada 1: Jugador=13, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 963 ---
# Resultado: Empató
# Jugada 1: Jugador=20, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 964 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 965 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 966 ---
# Resultado: Ganó
# Jugada 1: Jugador=16, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 967 ---
# Resultado: Ganó
# Jugada 1: Jugador=14, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 968 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 969 ---
# Resultado: Ganó
# Jugada 1: Jugador=11, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=21, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 21
#
# --- Episodio 970 ---
# Resultado: Ganó
# Jugada 1: Jugador=17, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 971 ---
# Resultado: Perdió
# Jugada 1: Jugador=11, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=18, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 972 ---
# Resultado: Perdió
# Jugada 1: Jugador=9, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 973 ---
# Resultado: Ganó
# Jugada 1: Jugador=6, Carta Crupier=5, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=16, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 974 ---
# Resultado: Ganó
# Jugada 1: Jugador=10, Carta Crupier=2, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=20, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 975 ---
# Resultado: Ganó
# Jugada 1: Jugador=17, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 976 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=4, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 977 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 978 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=1, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 979 ---
# Resultado: Perdió
# Jugada 1: Jugador=20, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 980 ---
# Resultado: Empató
# Jugada 1: Jugador=11, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=12, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=13, Carta Crupier=7, As Utilizable=0, Acción=Pedir carta
# Jugada 4: Jugador=17, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 981 ---
# Resultado: Perdió
# Jugada 1: Jugador=9, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=15, Carta Crupier=9, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 982 ---
# Resultado: Ganó
# Jugada 1: Jugador=15, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 983 ---
# Resultado: Perdió
# Jugada 1: Jugador=13, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugador terminó con: None
#
# --- Episodio 984 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 985 ---
# Resultado: Ganó
# Jugada 1: Jugador=14, Carta Crupier=3, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=19, Carta Crupier=3, As Utilizable=1, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 986 ---
# Resultado: Perdió
# Jugada 1: Jugador=14, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 14
#
# --- Episodio 987 ---
# Resultado: Ganó
# Jugada 1: Jugador=13, Carta Crupier=5, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 13
#
# --- Episodio 988 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 989 ---
# Resultado: Perdió
# Jugada 1: Jugador=18, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# --- Episodio 990 ---
# Resultado: Perdió
# Jugada 1: Jugador=15, Carta Crupier=7, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 991 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=8, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 992 ---
# Resultado: Ganó
# Jugada 1: Jugador=12, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 12
#
# --- Episodio 993 ---
# Resultado: Ganó
# Jugada 1: Jugador=15, Carta Crupier=3, As Utilizable=1, Acción=Pedir carta
# Jugada 2: Jugador=15, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 15
#
# --- Episodio 994 ---
# Resultado: Perdió
# Jugada 1: Jugador=16, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 16
#
# --- Episodio 995 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=6, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 996 ---
# Resultado: Ganó
# Jugada 1: Jugador=20, Carta Crupier=9, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 997 ---
# Resultado: Perdió
# Jugada 1: Jugador=20, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 20
#
# --- Episodio 998 ---
# Resultado: Ganó
# Jugada 1: Jugador=19, Carta Crupier=3, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 19
#
# --- Episodio 999 ---
# Resultado: Perdió
# Jugada 1: Jugador=17, Carta Crupier=2, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 17
#
# --- Episodio 1000 ---
# Resultado: Perdió
# Jugada 1: Jugador=12, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 2: Jugador=15, Carta Crupier=10, As Utilizable=0, Acción=Pedir carta
# Jugada 3: Jugador=18, Carta Crupier=10, As Utilizable=0, Acción=No quiero una carta
# Jugador terminó con: 18
#
# Resultados tras 1000 episodios:
# Victorias: 439
# Derrotas: 491
# Empates: 70
# Total ganadas: 439
# Total perdidas: 491
